# %% [markdown]
# Voici une liste de cours à faire avant le 04/09/2026

# %% [markdown]
# Juillet
# Understanding Data Engineer (en cours)
# Preprocessing for Machine Learning (En cours)
# Python Toolbox https://app.datacamp.com/learn/courses/python-toolbox
#
# Aout
# Hypothese testing https://app.datacamp.com/learn/courses/hypothesis-testing-in-python
# Data types in Python https://app.datacamp.com/learn/courses/data-types-in-python
# joining with Pandas https://app.datacamp.com/learn/courses/joining-data-with-pandas
#
# Skill Tracks:
# https://app.datacamp.com/learn/skill-tracks/python-programming-fundamentals
# https://app.datacamp.com/learn/skill-tracks/python-data-fundamentals

# %% [markdown]
# Pour Decembre
# Carreer Track
# OK : https://app.datacamp.com/learn/career-tracks/data-analyst-with-python
# Moyen : https://app.datacamp.com/learn/career-tracks/associate-data-analyst-in-sql
# Dur: https://app.datacamp.com/learn/career-tracks/associate-data-scientist-in-python
